# %%
import pandas as pd;
import numpy as np;
import seaborn as sns;
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3533ea80-bd36-4713-90cc-eda03c59a785" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3533ea80-bd36-4713-90cc-eda03c59a785">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filename = list(uploaded.keys())[0]
df = pd.read_csv(filename)
df.head()
# Out:
#   plane_number    source destination  duration_hours  is_direct  num_stops  \
# 0        SQ936     Paris      Berlin               7       True          0
# 1        JL723    London      Sydney               5      False          2
# 2        JL472    Berlin      Sydney              16      False          1
# 3        EK311    Mumbai       Tokyo               7       True          0
# 4        AF515  New York      Mumbai              11       True          0
#
#     stop_locations departure_time arrival_time stop_duration
# 0              NaN          01:15        08:15            0h
# 1  Dubai, New York          22:45        07:45            4h
# 2            Tokyo          23:15        16:15            1h
# 3              NaN          23:30        06:30            0h
# 4              NaN          07:30        18:30            0h

# %%
# !pip install openai==0.28
# !pip install python-dotenv
# !pip install pandas

# %%
import openai
openai.api_key="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"

# %%
with open (".env",'w') as filename:
  filename.write("openai.api_key=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")

# %%
from dotenv import load_dotenv
import os
import openai
load_dotenv()
OpenAI_API_KEY = os.getenv('openai.api_key')
openai.api_key = OpenAI_API_KEY

# %%
import openai

flight_info = """
Flight Data:
- plane_number: JL723, source: London, destination: Sydney, is_direct: False, num_stops: 2, stop_locations: Dubai, New York, departure_time: 22:45, arrival_time: 07:45

Question: What are the stopovers for flight JL723?
"""

response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful flight assistant. Use the data provided to answer the question."},
        {"role": "user", "content": flight_info}
    ]
)

print("🤖 Chatbot:", response['choices'][0]['message']['content'])
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-15-116179478> in <cell line: 0>()
#       8 """
#       9
# ---> 10 response = openai.ChatCompletion.create(
#      11     model="gpt-3.5-turbo",
#      12     messages=[
#
# /usr/local/lib/python3.11/dist-packages/openai/api_resources/chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# /usr/local/lib/python3.11/dist-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# --> 153         response, _, api_key = requestor.request(
# ...
